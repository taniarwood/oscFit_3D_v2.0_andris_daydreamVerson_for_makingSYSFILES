# %%
import os, sys
#sys.path.append('/Users/trwood/oscFit3D_v2.0_Tania/resources/ipython_notebooks')
sys.path.append('/Users/trwood/oscFit3D_v2.0_Tania_clean/oscFit3D_v2.0_Tania_Nov28_fwdFold')
sys.path.append('/Users/trwood/MSU_sample_sept2016/oscfit/MSU_tania_repickle/oscfitv2_repickle')
sys.path.append('/Users/trwood/oscFit3D_v2.0_Tania_clean/oscFit3D_v2.0_Tania_Nov28_fwdFold/user_settings')

# %%
modules_dir = '/Users/trwood/oscFit3D_v2.0_Tania_clean/oscFit3D_v2.0_Tania_Nov28_fwdFold/modules/'
sys.path.append(modules_dir)
# Importing modules
import pickle
import dataLoader, oscFit
import numpy as np
import oscfit_default_values as defs
from copy import deepcopy
import jp_mpl as jplot
# Out:
# /Users/trwood/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
data_dir = '/Users/trwood/MSU_sample_sept2016/data/'
#sim_dir = '/Users/trwood/MSU_sample_sept2016/oscfit/'
sim_dir = '/Users/trwood/MSU_sample_sept2016/oscfit/MSU_tania_repickle/oscfitv2_repickle/'

# %%
true_axis = np.array([[0.01, 10.],[10., 20.],[20.,40.],[40., np.inf]])

# %%
#JPBINNING from recent email
#bin_edges   = [10**np.linspace(0.75,1.75,9),
#                                               np.arccos(np.linspace(-1,1.,9))[::-1],
#                                               np.array([-3, 2, np.inf])],
#                                observables = ['reco_energy', 'reco_zenith', 'delta_llh'],



#msu_no_background_noData_baselineONLY.py
loader_nobkrd_a =  dataLoader.dataLoader(observables =
                                ['reco_energy', 'reco_zenith', 'delta_llh'],
                                bin_edges   =
                                #no events below 10GeV so start binning at 1
                                #smarter way cut out the frist 3 bins.  
                                #retain the same binning but get rid of below 10GeV
                                  #was 10**np.linspace([0.75,1.25,2])
                                [10**np.linspace(0.75,2.25,11),
                                 np.arccos(np.linspace(-1.,1.,9))[::-1],
                                 np.array([-3, 2, np.inf])],
                                 user = 'msu_no_background_noData_baselineONLY',
                                LEaxis = [],#np.linspace(1, 3.2, 21),      
                                #tells the fit if you want to use the polynomial or not
                                #do linear instead (see one at end of brackets
                #ask about nuspecs and muspecs.. not in msu original user i have as reference
                #but i want this to be as similar to my larson evaluation as possible
                                detsys_nuspecs = {},
                                detsys_muspecs = {},
                                weight_keys = ['tweight_e', 'tweight_mu_k', 'tweight_mu_p'],
                                extra_cuts = {'energy':true_axis[0]},
                                detsys_redo = True,
                                verbose = False,
                                table_nbins = 150)
# Out:
#  ************************************
#  **** oscFit3D v1.1 - dataLoader ****
#  ************************************
#
# dataLoader: Initializing user msu_no_background_noData_baselineONLY
# dataLoader: MC loaded successfully!
# dataLoader: Muon background templates loaded successfully!
# dataLoader: Generating new systematic histograms
# dataLoader: No MC for atmospheric muons
# dataLoader: Done loading systematic variations
# dataLoader: Combining systematics for  nue
# dataLoader: Not building systematic functions for nue
# dataLoader: Combining systematics for  numu
# dataLoader: Not building systematic functions for numu
# dataLoader: Combining systematics for  nutau
# dataLoader: Not building systematic functions for nutau
# dataLoader: Combining systematics for  nc
# dataLoader: Not building systematic functions for nc
# dataLoader: Combining systematics for  atmmu
# dataLoader: Not building systematic functions for atmmu

# %%
#make a fully new copy of loader_dict, ie don't just copy the location of the pointer
from copy import deepcopy
loader_dict = deepcopy(loader_nobkrd_a.iniDict)

# %%
#change this entry in the 
loader_dict['extra_cuts'] =  {'energy':true_axis[1]}
loader_nobkrd_b= dataLoader.dataLoader(**loader_dict)
# Out:
#  ************************************
#  **** oscFit3D v1.1 - dataLoader ****
#  ************************************
#
# dataLoader: Initializing user msu_no_background_noData_baselineONLY
# dataLoader: MC loaded successfully!
# dataLoader: Muon background templates loaded successfully!
# dataLoader: Generating new systematic histograms
# dataLoader: No MC for atmospheric muons
# dataLoader: Done loading systematic variations
# dataLoader: Combining systematics for  nue
# dataLoader: Not building systematic functions for nue
# dataLoader: Combining systematics for  numu
# dataLoader: Not building systematic functions for numu
# dataLoader: Combining systematics for  nutau
# dataLoader: Not building systematic functions for nutau
# dataLoader: Combining systematics for  nc
# dataLoader: Not building systematic functions for nc
# dataLoader: Combining systematics for  atmmu
# dataLoader: Not building systematic functions for atmmu

# %%
loader_dict['extra_cuts'] =  {'energy':true_axis[2]}
loader_nobkrd_c= dataLoader.dataLoader(**loader_dict)
# Out:
#  ************************************
#  **** oscFit3D v1.1 - dataLoader ****
#  ************************************
#
# dataLoader: Initializing user msu_no_background_noData_baselineONLY
# dataLoader: MC loaded successfully!
# dataLoader: Muon background templates loaded successfully!
# dataLoader: Generating new systematic histograms
# dataLoader: No MC for atmospheric muons
# dataLoader: Done loading systematic variations
# dataLoader: Combining systematics for  nue
# dataLoader: Not building systematic functions for nue
# dataLoader: Combining systematics for  numu
# dataLoader: Not building systematic functions for numu
# dataLoader: Combining systematics for  nutau
# dataLoader: Not building systematic functions for nutau
# dataLoader: Combining systematics for  nc
# dataLoader: Not building systematic functions for nc
# dataLoader: Combining systematics for  atmmu
# dataLoader: Not building systematic functions for atmmu

# %%
loader_dict['extra_cuts'] =  {'energy':true_axis[3]}
loader_nobkrd_d= dataLoader.dataLoader(**loader_dict)
# Out:
#  ************************************
#  **** oscFit3D v1.1 - dataLoader ****
#  ************************************
#
# dataLoader: Initializing user msu_no_background_noData_baselineONLY
# dataLoader: MC loaded successfully!
# dataLoader: Muon background templates loaded successfully!
# dataLoader: Generating new systematic histograms
# dataLoader: No MC for atmospheric muons
# dataLoader: Done loading systematic variations
# dataLoader: Combining systematics for  nue
# dataLoader: Not building systematic functions for nue
# dataLoader: Combining systematics for  numu
# dataLoader: Not building systematic functions for numu
# dataLoader: Combining systematics for  nutau
# dataLoader: Not building systematic functions for nutau
# dataLoader: Combining systematics for  nc
# dataLoader: Not building systematic functions for nc
# dataLoader: Combining systematics for  atmmu
# dataLoader: Not building systematic functions for atmmu

# %%
sys.path.append('/Users/trwood/oscFit3D_v2.0_Tania/user_settings')
loader_dict['extra_cuts'] =  {}
loader_dict['user'] = 'noSystematicSets_new_finalized_msu_20122014_holeice2'
loader_bkrd_nu= dataLoader.dataLoader(**loader_dict)
# Out:
#  ************************************
#  **** oscFit3D v1.1 - dataLoader ****
#  ************************************
#
# dataLoader: Initializing user noSystematicSets_new_finalized_msu_20122014_holeice2
# dataLoader: MC loaded successfully!
# dataLoader: Muon background templates loaded successfully!
# dataLoader: Generating new systematic histograms
# dataLoader: No MC for atmospheric muons
# dataLoader: Done loading systematic variations
# dataLoader: Combining systematics for  nue
# dataLoader: Not building systematic functions for nue
# dataLoader: Combining systematics for  numu
# dataLoader: Not building systematic functions for numu
# dataLoader: Combining systematics for  nutau
# dataLoader: Not building systematic functions for nutau
# dataLoader: Combining systematics for  nc
# dataLoader: Not building systematic functions for nc
# dataLoader: Combining systematics for  atmmu
# dataLoader: Not building systematic functions for atmmu

# %%
loader_dict['extra_cuts'] =  {}
loader_dict['user'] = 'msu_BKGRND_only'
loader_pureBkrd = dataLoader.dataLoader(**loader_dict)
# Out:
#  ************************************
#  **** oscFit3D v1.1 - dataLoader ****
#  ************************************
#
# dataLoader: Initializing user msu_BKGRND_only
# dataLoader: MC loaded successfully!
# dataLoader: Muon background templates loaded successfully!
# dataLoader: Generating new systematic histograms
# dataLoader: No MC for atmospheric muons
# dataLoader: Done loading systematic variations
# dataLoader: Combining systematics for  nue
# dataLoader: Not building systematic functions for nue
# dataLoader: Combining systematics for  numu
# dataLoader: Not building systematic functions for numu
# dataLoader: Combining systematics for  nutau
# dataLoader: Not building systematic functions for nutau
# dataLoader: Combining systematics for  nc
# dataLoader: Not building systematic functions for nc
# dataLoader: Combining systematics for  atmmu
# dataLoader: Not building systematic functions for atmmu

# %%
#data_settings.update({'norm_atmu':      100.})

# %%
data_settings = deepcopy(defs.default_data_settings)
data_settings.update({'dm31':                  0.0025,
                   'theta23':                  0.78,
                   'theta13':                  0.155,
                   'norm_tau':                 1.,
                   'axm_qe':                   0.,
                   'axm_res':                  0.,
                   'norm_nu':                  3.6, # In years!
                   'norm_e':                   1.,
                   'domeff':                   1.,
                   'nu_pi_scale':              1.,
                   'hole_ice':                 0.02,
                   'atmmu_template':           'data',
                   'simulation':               'baseline',
                   'oscTables':                False,
            
                   'ma_variations':            False,
                   'add_detector_systematics': False,
                   'norm_atmmu':                None,
                   'pid_bias':                 0.,
                   'domeff':                   1.,
                   'hole_ice':                 0.02,
                   'hi_fwd':                   0., # MSU parameterization of the forward impact angle
                   'had_escale':               1.,
                   'oscMode':                  'TwoNeutrino', 
                   'ma_variations':            False,
                   'add_detector_systematics': False,   
                   'norm_noise':                0.0,
                    'atmmu_f':                  0.05   })

# %%
#need to check that my fit settings that I am fixing match the data settings
fit_settings = deepcopy(defs.default_fit_settings)
fit_settings_fix    = {
    'simulation':     'baseline',
    'dm31':           [0.0025, False, 'NH'],
    'theta23':        [0.78, False],
    'theta13':        [0.155, False],
    'oscMode':        'TwoNeutrino',
    'oscTables':      False,         #used to be False.  need to think about the tables.  need to understand resolution to set n bins
    'norm':           [1., True],    #try once with this true and once with this false, same settings
    'norm_1':         [1., True],    #minuit qestion " is it Fixed? True means yes, it is fixed.
    'norm_2':         [1., False], 
    'norm_3':         [1., False], 
    'norm_4':         [1., False], 
    'norm_e':         [1., True],
    'norm_tau':       [1., True],
    'nu_nubar':       [1., True],
    'nubar_ratio':    [0., True],
    'uphor_ratio':    [0., True],
    'nu_pi_scale':    [1, False],

    'gamma':          [0., True],
    'axm_qe':         [0., True],
    'axm_res':        [0., True],
    'pid_bias':       [0., True],
    'hole_ice':       [0.02, True],
    'mix_angle':      [1.0, True, 1.],

    'norm_nc':        [1., True],
    'domeff':         [1., False],
    'had_escale':     [1., True],
    'atmmu_f':        [0.05, False, 'data'],
    'noise_f':        [0.0, True],
    'detector_syst':  False,
    'include_priors': True,
    'printMode':      -1}

# %%
data_hiso_a = loader_nobkrd_a.loadMCasData(data_settings,
                                     statistical_fluctuations=False)
data_hiso_b = loader_nobkrd_b.loadMCasData(data_settings,
                                     statistical_fluctuations=False)
data_histo_c = loader_nobkrd_c.loadMCasData(data_settings,
                                     statistical_fluctuations=False)
data_histo_d = loader_nobkrd_d.loadMCasData(data_settings,
                                     statistical_fluctuations=False)
data_histo_pureBKD = loader_pureBkrd.loadMCasData(data_settings,
                               statistical_fluctuations=False)
data_histo_bkrd_PlusNu =loader_bkrd_nu.loadMCasData(data_settings,
                                         statistical_fluctuations=False)
# Out:
# dataLoader: using the atmosperhic muon fraction given (not normalizations)
# dataLoader: atmmu_norm  inf , noise_norm 0.0
# dataLoader: using the atmosperhic muon fraction given (not normalizations)
# dataLoader: atmmu_norm  inf , noise_norm 0.0
# dataLoader: using the atmosperhic muon fraction given (not normalizations)
# dataLoader: atmmu_norm  inf , noise_norm 0.0
# dataLoader: using the atmosperhic muon fraction given (not normalizations)
# dataLoader: atmmu_norm  inf , noise_norm 0.0
# dataLoader: using the atmosperhic muon fraction given (not normalizations)
# dataLoader: atmmu_norm  0.0 , noise_norm 0.0
# dataLoader: using the atmosperhic muon fraction given (not normalizations)
# dataLoader: atmmu_norm  0.110477397975 , noise_norm 0.0

# %%
import iminuit

# %%
fitter = oscFit.fitOscParams()
# Out:
#  ************************************
#  ****** oscFit3D v1.1 - oscFit ******
#  ************************************

# %%
#fit_priors = {'hole_ice':[0.02, 0.01],
#              'gamma':[0.05, 0.1],
#              'norm_e':[1., 0.2]}

# %%
oscFitResults_fixed, Minuit2Results_fixed=fitter(data_histograms=[data_histo_bkrd_PlusNu],
        data_loaders=[loader_nobkrd_a,loader_nobkrd_b,loader_nobkrd_c,loader_nobkrd_d,loader_pureBkrd],
              fit_settings=fit_settings_fix,
               ncalls               = 1000, # For migrad. Simplex will use twice the number.
               store_fit_details    = True,
               return_minuit_object = True)
# Out:
# oscFit: Fitter running in TwoNeutrino mode
# oscFit: 64045.9571541  events in data
# oscFit: Fitting in normal hierarchy mode
# oscFit: found octant in settings B
# found octant constrain to theta23 as (0.0, 1.5707963267948966)
# -338456.86752
# oscFit: Testing the LLH function  -338456.867517
# oscFit: Fit settings
# 	noise_f 	[0.0, True]
# 	pid_bias 	[0.0, True]
# 	octant 	B
# 	hi_fwd 	[0.0, True]
# 	blind_keys 	[]
# 	printMode 	-1
# 	oscMode 	TwoNeutrino
# 	include_priors 	True
# 	norm_4 	[1.0, False]
# 	atmmu_f 	[0.05, False, 'data']
# 	norm_1 	[1.0, True]
# 	dm31 	[0.0025, False, 'NH']
# 	theta23 	[0.78, False]
# 	norm_2 	[1.0, False]
# 	detector_syst 	False
# 	remove_blind_keys 	True
# 	uphor_ratio 	[0.0, True]
# 	oscTables 	False
# 	norm 	[1.0, True]
# 	norm_3 	[1.0, False]
# 	axm_res 	[0.0, True]
# 	norm_tau 	[1.0, True]
# 	theta24 	[0.0, True]
# 	nubar_ratio 	[0.0, True]
# 	dm41 	[0.0, True]
# 	norm_nc 	[1.0, True]
# 	domeff 	[1.0, False]
# 	minimizer 	migrad
# 	hole_ice 	[0.02, True]
# 	nu_nubar 	[1.0, True]
# 	baseline_llh 	0.0
# 	had_escale 	[1.0, True]
# 	theta34 	[0.0, True]
# 	mix_angle 	[1.0, True, 1.0]
# 	nu_pi_scale 	[1, False]
# 	simulation 	baseline
# 	norm_e 	[1.0, True]
# 	axm_qe 	[0.0, True]
# 	llh_space 	poisson
# 	theta13 	[0.155, False]
# 	gamma 	[0.0, True]
#
# oscFitL: Tolerance for iminuit:  0.01
# oscFit: Firing up the minimizer!
#
#
#       -LLH   |   dm31 | norm_2 | norm_3 | norm_4 | atmmu_f | nu_pi_scale |
# -338456.86752  +0.00250  +1.00000  +1.00000  +1.00000  +0.05000  +1.00000
# -338441.48462  +0.00292  +1.00000  +1.00000  +1.00000  +0.05000  +1.00000
# -338438.10215  +0.00210  +1.00000  +1.00000  +1.00000  +0.05000  +1.00000
# -338456.69605  +0.00254  +1.00000  +1.00000  +1.00000  +0.05000  +1.00000
# -338456.69326  +0.00246  +1.00000  +1.00000  +1.00000  +0.05000  +1.00000
# -338456.78725  +0.00253  +1.00000  +1.00000  +1.00000  +0.05000  +1.00000
# -338456.78636  +0.00247  +1.00000  +1.00000  +1.00000  +0.05000  +1.00000
# -338444.09302  +0.00250  +1.12210  +1.00000  +1.00000  +0.05000  +1.00000
# -338442.16609  +0.00250  +0.87790  +1.00000  +1.00000  +0.05000  +1.00000
# -338456.73098  +0.00250  +1.01224  +1.00000  +1.00000  +0.05000  +1.00000
# -338456.72905  +0.00250  +0.98776  +1.00000  +1.00000  +0.05000  +1.00000
# -338456.78726  +0.00250  +1.00938  +1.00000  +1.00000  +0.05000  +1.00000
# -338456.78639  +0.00250  +0.99062  +1.00000  +1.00000  +0.05000  +1.00000
# -338441.23345  +0.00250  +1.00000  +1.12210  +1.00000  +0.05000  +1.00000
# -338438.85134  +0.00250  +1.00000  +0.87790  +1.00000  +0.05000  +1.00000
# -338456.70033  +0.00250  +1.00000  +1.01224  +1.00000  +0.05000  +1.00000
# -338456.69794  +0.00250  +1.00000  +0.98776  +1.00000  +0.05000  +1.00000
# -338456.78722  +0.00250  +1.00000  +1.00847  +1.00000  +0.05000  +1.00000
# -338456.78643  +0.00250  +1.00000  +0.99153  +1.00000  +0.05000  +1.00000
# -338426.48423  +0.00250  +1.00000  +1.00000  +1.12210  +0.05000  +1.00000
# -338420.80336  +0.00250  +1.00000  +1.00000  +0.87790  +0.05000  +1.00000
# -338456.53879  +0.00250  +1.00000  +1.00000  +1.01224  +0.05000  +1.00000
# -338456.53311  +0.00250  +1.00000  +1.00000  +0.98776  +0.05000  +1.00000
# -338456.78716  +0.00250  +1.00000  +1.00000  +1.00604  +0.05000  +1.00000
# -338456.78648  +0.00250  +1.00000  +1.00000  +0.99396  +0.05000  +1.00000
# -338456.59865  +0.00250  +1.00000  +1.00000  +1.00000  +0.05000  +1.04042
# -338456.58328  +0.00250  +1.00000  +1.00000  +1.00000  +0.05000  +0.95999
# -338456.78805  +0.00250  +1.00000  +1.00000  +1.00000  +0.05000  +1.02178
# -338456.78563  +0.00250  +1.00000  +1.00000  +1.00000  +0.05000  +0.97833
# -338455.84068  +0.00250  +1.00000  +1.00000  +1.00000  +0.05411  +1.00000
# -338455.89772  +0.00250  +1.00000  +1.00000  +1.00000  +0.04604  +1.00000
# -338456.78616  +0.00250  +1.00000  +1.00000  +1.00000  +0.05115  +1.00000
# -338456.78747  +0.00250  +1.00000  +1.00000  +1.00000  +0.04886  +1.00000
# -338456.86751  +0.00250  +1.00003  +1.00002  +1.00001  +0.05000  +1.00016
# -338456.86752  +0.00250  +1.00001  +1.00001  +1.00000  +0.05000  +1.00006
# -338456.86752  +0.00250  +1.00000  +1.00000  +1.00000  +0.05000  +1.00003
# -338456.86752  +0.00250  +1.00000  +1.00000  +1.00000  +0.05000  +1.
#
#
#  ************ FIT FINISHED ************
#
# Migrad EDM	5.66669706494e-11
# Migrad NCalls	69
#
# oscFit: Loader  4  nonzero bins:  160
# oscFit: Total nonzero bins:  160
#
#  **** oscFit3D results ****
# add_detector_systematics 	False
# atmmu_f 	0.05 	0.00322417410983
# atmmu_template 	data
# axm_qe 	0.0 	0.5
# axm_res 	0.0 	0.5
# chi_squared 	1.08480130145e-25
# dm31 	0.0025 	7.73463650434e-05
# dm41 	0.0 	0.5
# domeff 	1.0 	0.02
# expected_events 	[64045.957154097414]
# expected_events_mc 	[64045.957154097399]
# gamma 	0.0 	0.1
# had_escale 	1.0 	0.03
# hesse_errors 	True
# hi_fwd 	0.0 	0.01
# hole_ice 	0.02 	0.001
# llh 	-338456.867517
# min_routine 	migrad
# mix_angle 	1.0 	0.1
# noise_f 	0.0 	0.01
# nonzero_bins 	160
# norm 	1.0 	1e-05
# norm_1 	1.0 	0.3
# norm_2 	1.0 	0.0399079559133
# norm_3 	1.0 	0.0249370706003
# norm_4 	1.0 	0.024545730755
# norm_atmmu 	0.110477397975
# norm_e 	1.0 	0.05
# norm_nc 	1.0 	0.1
# norm_noise 	0
# norm_nu 	3.6
# norm_tau 	1.0 	0.1
# nu_nubar 	1.0 	0.6
# nu_pi_scale 	1.0 	0.0622312339272
# nubar_ratio 	0.0 	0.5
# oscMode 	TwoNeutrino
# pid_bias 	0.0 	0.01
# simulation 	baseline
# successful_fit 	True
# theta13 	0.155 	0.008
# theta23 	0.78 	0.0001
# theta24 	0.0 	0.2
# theta34 	0.0 	0.2
# uphor_ratio 	0.0 	0.5
#
#
# The fit was successful!

# %%
oscFitResults_fixed.update({'data_settings': data_settings})

# %%
Minuit2Results_fixed.print_matrix()
# Out:
#             <table>
#                 <tr>
#                     <td><a onclick="$('#fQlDMYAhzi').toggle()" href="#">+</a></td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             dm31
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             norm_2
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             norm_3
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             norm_4
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             nu_pi_scale
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             atmmu_f
#             </div>
#             </div>
#             </td>
#
#                 </tr>
#
#             <tr>
#                 <td>dm31</td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(187,218,168)">
#                 -0.26
#                 </td>
#
#                 <td style="background-color:rgb(174,237,177)">
#                 0.12
#                 </td>
#
#                 <td style="background-color:rgb(168,247,182)">
#                 -0.05
#                 </td>
#
#                 <td style="background-color:rgb(182,226,172)">
#                 0.20
#                 </td>
#
#                 <td style="background-color:rgb(179,230,174)">
#                 -0.18
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>norm_2</td>
#
#                 <td style="background-color:rgb(187,218,168)">
#                 -0.26
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(183,225,171)">
#                 0.21
#                 </td>
#
#                 <td style="background-color:rgb(234,149,133)">
#                 0.77
#                 </td>
#
#                 <td style="background-color:rgb(181,226,172)">
#                 -0.20
#                 </td>
#
#                 <td style="background-color:rgb(166,249,184)">
#                 0.04
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>norm_3</td>
#
#                 <td style="background-color:rgb(174,237,177)">
#                 0.12
#                 </td>
#
#                 <td style="background-color:rgb(183,225,171)">
#                 0.21
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(182,226,172)">
#                 0.20
#                 </td>
#
#                 <td style="background-color:rgb(191,212,165)">
#                 -0.31
#                 </td>
#
#                 <td style="background-color:rgb(189,215,166)">
#                 -0.28
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>norm_4</td>
#
#                 <td style="background-color:rgb(168,247,182)">
#                 -0.05
#                 </td>
#
#                 <td style="background-color:rgb(234,149,133)">
#                 0.77
#                 </td>
#
#                 <td style="background-color:rgb(182,226,172)">
#                 0.20
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(173,240,179)">
#                 -0.10
#                 </td>
#
#                 <td style="background-color:rgb(172,241,179)">
#                 -0.10
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>nu_pi_scale</td>
#
#                 <td style="background-color:rgb(182,226,172)">
#                 0.20
#                 </td>
#
#                 <td style="background-color:rgb(181,226,172)">
#                 -0.20
#                 </td>
#
#                 <td style="background-color:rgb(191,212,165)">
#                 -0.31
#                 </td>
#
#                 <td style="background-color:rgb(173,240,179)">
#                 -0.10
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(184,223,170)">
#                 -0.23
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>atmmu_f</td>
#
#                 <td style="background-color:rgb(179,230,174)">
#                 -0.18
#                 </td>
#
#                 <td style="background-color:rgb(166,249,184)">
#                 0.04
#                 </td>
#
#                 <td style="background-color:rgb(189,215,166)">
#                 -0.28
#                 </td>
#
#                 <td style="background-color:rgb(172,241,179)">
#                 -0.10
#                 </td>
#
#                 <td style="background-color:rgb(184,223,170)">
#                 -0.23
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#             </tr>
#             </table>
#
#             <pre id="fQlDMYAhzi" style="display:none;">
#             <textarea rows="21" cols="50" onclick="this.select()" readonly>%\usepackage[table]{xcolor} % include this for color
# %\usepackage{rotating} % include this for rotate header
# %\documentclass[xcolor=table]{beamer} % for beamer
# \begin{tabular}{|c|c|c|c|c|c|c|}
# \hline
# \rotatebox{90}{} & \rotatebox{90}{dm31} & \rotatebox{90}{$norm_{2}$} & \rotatebox{90}{$norm_{3}$} & \rotatebox{90}{$norm_{4}$} & \rotatebox{90}{$\nu$ $\pi_{scale}$} & \rotatebox{90}{$atmmu_{f}$}\\
# \hline
# dm31 & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{187,218,168} -0.26 & \cellcolor[RGB]{174,237,177} 0.12 & \cellcolor[RGB]{168,247,182} -0.05 & \cellcolor[RGB]{182,226,172} 0.20 & \cellcolor[RGB]{179,230,174} -0.18\\
# \hline
# $norm_{2}$ & \cellcolor[RGB]{187,218,168} -0.26 & \cellcolor[RGB]{255,117,117} 1.00 & \cellcol

# %%
#oscFitResults_fixed, Minuit2Results_fixed

# %%
pickle.dump(Results_oscfit_fixed,open('/Users/trwood/MSU_sample_sept2016/oscfit/MSU_tania_repickle/oscfitv2_repickle/BaseLineOnly_noSys_fit_ForwardFold_identicalSettingsFixedFloat.pckl', 'w'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-d5388664f0bf> in <module>()
# ----> 1 pickle.dump(Results_oscfit_fixed,open('/Users/trwood/MSU_sample_sept2016/oscfit/MSU_tania_repickle/oscfitv2_repickle/BaseLineOnly_noSys_fit_ForwardFold_identicalSettingsFixedFloat.pckl', 'w'))
#
# NameError: name 'Results_oscfit_fixed' is not defined
